# %%
import torch
import models_jw
from utils import *
from tqdm import tqdm
import numpy as np
from configs import paramsuper, getters
from helpers import *

# %%
"""    
    [100]*8,
    [200]*8,
    [300]*8,
    range(100, 900, 100),
    range(100, 500, 50),
    range(450, 50, -50),
    range(800, 0, -100),
    [400]*8,
    [500]*8,
    [600]*8,
"""
# Out:
# '    \n    [100]*8,\n    [200]*8,\n    [300]*8,\n    range(100, 900, 100),\n    range(100, 500, 50),\n    range(450, 50, -50),\n    range(800, 0, -100),\n    [400]*8,\n    [500]*8,\n    [600]*8,\n'

# %%
plot_hists([f"2_{i}_0_0_bh" for i in range(7)], smallheads=False)
# Out:
# 7it [01:04,  9.16s/it]

# %%
plot_hists([f"2_{i}_1_0_bh" for i in range(7)], smallheads=False)
# Out:
# 7it [01:05,  9.41s/it]

# %%
plot_hists([f"1_{i}_0_0_bh" for i in range(7)], smallheads=False)
# Out:
# 7it [01:04,  9.19s/it]

# %%
plot_hists([f"1_{i}_1_0_bh" for i in range(7)], smallheads=False)
# Out:
# 7it [01:04,  9.18s/it]

# %%
plot_hists([f"1_{i}_0_0" for i in range(10)], smallheads=True)
# Out:
# 10it [01:31,  9.19s/it]

# %%
plot_hists([f"1_{i}_1_0" for i in range(10)], smallheads=True)
# Out:
# 10it [01:31,  9.18s/it]

# %%
plot_hists([f"2_{i}_0_0" for i in range(1,10)], smallheads=True)
# Out:
# 9it [01:22,  9.19s/it]

# %%
plot_hists([f"2_{i}_1_0" for i in range(10)], smallheads=True)
# Out:
# 10it [01:31,  9.18s/it]
